# %%
import pandas as pd

# Point to any one of your review CSVs:
sample_path = "../data/kg/metadata_triples.csv"

# Read zero rows—just grab the header
df = pd.read_csv(sample_path)
df.head(10)
# Out:
#    subject        predicate                            object
# 0     6499  in_neighborhood                              Belm
# 1     6499      has_amenity                       Mini fridge
# 2     6499      has_amenity                      Dining table
# 3     6499      has_amenity               Ethernet connection
# 4     6499      has_amenity                    Cooking basics
# 5     6499      has_amenity                     First aid kit
# 6     6499      has_amenity                           Kitchen
# 7     6499      has_amenity  Paid street parking off premises
# 8     6499      has_amenity                        Bed linens
# 9     6499      has_amenity                 Laundromat nearby
